# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/benign_traffic.csv')
df2 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/gafgyt/combo.csv')
df3 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/gafgyt/junk.csv')
df4 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/gafgyt/scan.csv')
df5 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/gafgyt/tcp.csv')
df6 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/gafgyt/udp.csv')
df7 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/mirai/ack.csv')
df8 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/mirai/scan.csv')
df9 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/mirai/syn.csv')
df10 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/mirai/udp.csv')
df11 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1002_WHT_Security_Camera/mirai/udpplain.csv')

# %%
df1['Label'] = 'BENIGN'
df1.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46585 entries, 0 to 46584
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    MI_dir_L5_weight       46585 non-null  float64
#  1    MI_dir_L5_mean         46585 non-null  float64
#  2    MI_dir_L5_variance     46585 non-null  float64
#  3    MI_dir_L3_weight       46585 non-null  float64
#  4    MI_dir_L3_mean         46585 non-null  float64
#  5    MI_dir_L3_variance     46585 non-null  float64
#  6    MI_dir_L1_weight       46585 non-null  float64
#  7    MI_dir_L1_mean         46585 non-null  float64
#  8    MI_dir_L1_variance     46585 non-null  float64
#  9    MI_dir_L0.1_weight     46585 non-null  float64
#  10   MI_dir_L0.1_mean       46585 non-null  float64
#  11   MI_dir_L0.1_variance   46585 non-null  float64
#  12   MI_dir_L0.01_weight    46585 non-null  float64
#  13   MI_dir_L0.01_mean      46585 non-null  float64
# ...

# %%
df_gafgyt = pd.concat([df2, df3, df4, df5, df6])
df_gafgyt['Label'] = 'gafgyt'
df_gafgyt.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 303223 entries, 0 to 103719
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       303223 non-null  float64
#  1    MI_dir_L5_mean         303223 non-null  float64
#  2    MI_dir_L5_variance     303223 non-null  float64
#  3    MI_dir_L3_weight       303223 non-null  float64
#  4    MI_dir_L3_mean         303223 non-null  float64
#  5    MI_dir_L3_variance     303223 non-null  float64
#  6    MI_dir_L1_weight       303223 non-null  float64
#  7    MI_dir_L1_mean         303223 non-null  float64
#  8    MI_dir_L1_variance     303223 non-null  float64
#  9    MI_dir_L0.1_weight     303223 non-null  float64
#  10   MI_dir_L0.1_mean       303223 non-null  float64
#  11   MI_dir_L0.1_variance   303223 non-null  float64
#  12   MI_dir_L0.01_weight    303223 non-null  float64
# ...

# %%
df_mirai = pd.concat([df7, df8, df9, df10, df11])
df_mirai['Label'] = 'mirai'
df_mirai.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 513248 entries, 0 to 78243
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       513248 non-null  float64
#  1    MI_dir_L5_mean         513248 non-null  float64
#  2    MI_dir_L5_variance     513248 non-null  float64
#  3    MI_dir_L3_weight       513248 non-null  float64
#  4    MI_dir_L3_mean         513248 non-null  float64
#  5    MI_dir_L3_variance     513248 non-null  float64
#  6    MI_dir_L1_weight       513248 non-null  float64
#  7    MI_dir_L1_mean         513248 non-null  float64
#  8    MI_dir_L1_variance     513248 non-null  float64
#  9    MI_dir_L0.1_weight     513248 non-null  float64
#  10   MI_dir_L0.1_mean       513248 non-null  float64
#  11   MI_dir_L0.1_variance   513248 non-null  float64
#  12   MI_dir_L0.01_weight    513248 non-null  float64
# ...

# %%
df = pd.concat([df1, df_gafgyt, df_mirai])

df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 863056 entries, 0 to 78243
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       863056 non-null  float64
#  1    MI_dir_L5_mean         863056 non-null  float64
#  2    MI_dir_L5_variance     863056 non-null  float64
#  3    MI_dir_L3_weight       863056 non-null  float64
#  4    MI_dir_L3_mean         863056 non-null  float64
#  5    MI_dir_L3_variance     863056 non-null  float64
#  6    MI_dir_L1_weight       863056 non-null  float64
#  7    MI_dir_L1_mean         863056 non-null  float64
#  8    MI_dir_L1_variance     863056 non-null  float64
#  9    MI_dir_L0.1_weight     863056 non-null  float64
#  10   MI_dir_L0.1_mean       863056 non-null  float64
#  11   MI_dir_L0.1_variance   863056 non-null  float64
#  12   MI_dir_L0.01_weight    863056 non-null  float64
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# mirai     513248
# gafgyt    303223
# BENIGN     46585
# Name: count, dtype: int64

# %%
pd.DataFrame(df).to_csv("./NBaIoT_7.csv", index=False)
