# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/benign_traffic.csv')
df2 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/gafgyt/combo.csv')
df3 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/gafgyt/junk.csv')
df4 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/gafgyt/scan.csv')
df5 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/gafgyt/tcp.csv')
df6 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/gafgyt/udp.csv')
df7 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/mirai/ack.csv')
df8 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/mirai/scan.csv')
df9 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/mirai/syn.csv')
df10 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/mirai/udp.csv')
df11 = pd.read_csv('/home/administrator/dataset/NBaIoT/Danmini_Doorbell/mirai/udpplain.csv')

# %%
df1['Label'] = 'BENIGN'
df1.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49548 entries, 0 to 49547
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    MI_dir_L5_weight       49548 non-null  float64
#  1    MI_dir_L5_mean         49548 non-null  float64
#  2    MI_dir_L5_variance     49548 non-null  float64
#  3    MI_dir_L3_weight       49548 non-null  float64
#  4    MI_dir_L3_mean         49548 non-null  float64
#  5    MI_dir_L3_variance     49548 non-null  float64
#  6    MI_dir_L1_weight       49548 non-null  float64
#  7    MI_dir_L1_mean         49548 non-null  float64
#  8    MI_dir_L1_variance     49548 non-null  float64
#  9    MI_dir_L0.1_weight     49548 non-null  float64
#  10   MI_dir_L0.1_mean       49548 non-null  float64
#  11   MI_dir_L0.1_variance   49548 non-null  float64
#  12   MI_dir_L0.01_weight    49548 non-null  float64
#  13   MI_dir_L0.01_mean      49548 non-null  float64
# ...

# %%
df_gafgyt = pd.concat([df2, df3, df4, df5, df6])
df_gafgyt['Label'] = 'gafgyt'
df_gafgyt.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316650 entries, 0 to 105873
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       316650 non-null  float64
#  1    MI_dir_L5_mean         316650 non-null  float64
#  2    MI_dir_L5_variance     316650 non-null  float64
#  3    MI_dir_L3_weight       316650 non-null  float64
#  4    MI_dir_L3_mean         316650 non-null  float64
#  5    MI_dir_L3_variance     316650 non-null  float64
#  6    MI_dir_L1_weight       316650 non-null  float64
#  7    MI_dir_L1_mean         316650 non-null  float64
#  8    MI_dir_L1_variance     316650 non-null  float64
#  9    MI_dir_L0.1_weight     316650 non-null  float64
#  10   MI_dir_L0.1_mean       316650 non-null  float64
#  11   MI_dir_L0.1_variance   316650 non-null  float64
#  12   MI_dir_L0.01_weight    316650 non-null  float64
# ...

# %%
df_mirai = pd.concat([df7, df8, df9, df10, df11])
df_mirai['Label'] = 'mirai'
df_mirai.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 652100 entries, 0 to 81981
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       652100 non-null  float64
#  1    MI_dir_L5_mean         652100 non-null  float64
#  2    MI_dir_L5_variance     652100 non-null  float64
#  3    MI_dir_L3_weight       652100 non-null  float64
#  4    MI_dir_L3_mean         652100 non-null  float64
#  5    MI_dir_L3_variance     652100 non-null  float64
#  6    MI_dir_L1_weight       652100 non-null  float64
#  7    MI_dir_L1_mean         652100 non-null  float64
#  8    MI_dir_L1_variance     652100 non-null  float64
#  9    MI_dir_L0.1_weight     652100 non-null  float64
#  10   MI_dir_L0.1_mean       652100 non-null  float64
#  11   MI_dir_L0.1_variance   652100 non-null  float64
#  12   MI_dir_L0.01_weight    652100 non-null  float64
# ...

# %%
df = pd.concat([df1, df_gafgyt, df_mirai])

df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1018298 entries, 0 to 81981
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count    Dtype
# ---   ------                 --------------    -----
#  0    MI_dir_L5_weight       1018298 non-null  float64
#  1    MI_dir_L5_mean         1018298 non-null  float64
#  2    MI_dir_L5_variance     1018298 non-null  float64
#  3    MI_dir_L3_weight       1018298 non-null  float64
#  4    MI_dir_L3_mean         1018298 non-null  float64
#  5    MI_dir_L3_variance     1018298 non-null  float64
#  6    MI_dir_L1_weight       1018298 non-null  float64
#  7    MI_dir_L1_mean         1018298 non-null  float64
#  8    MI_dir_L1_variance     1018298 non-null  float64
#  9    MI_dir_L0.1_weight     1018298 non-null  float64
#  10   MI_dir_L0.1_mean       1018298 non-null  float64
#  11   MI_dir_L0.1_variance   1018298 non-null  float64
#  12   MI_dir_L0.01_weight    1018298 non-null  float64
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# mirai     652100
# gafgyt    316650
# BENIGN     49548
# Name: count, dtype: int64

# %%
pd.DataFrame(df).to_csv("./NBaIoT_1.csv", index=False)
