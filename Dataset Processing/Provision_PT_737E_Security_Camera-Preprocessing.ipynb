# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/benign_traffic.csv')
df2 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/gafgyt/combo.csv')
df3 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/gafgyt/junk.csv')
df4 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/gafgyt/scan.csv')
df5 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/gafgyt/tcp.csv')
df6 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/gafgyt/udp.csv')
df7 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/mirai/ack.csv')
df8 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/mirai/scan.csv')
df9 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/mirai/syn.csv')
df10 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/mirai/udp.csv')
df11 = pd.read_csv('/home/administrator/dataset/NBaIoT/Provision_PT_737E_Security_Camera/mirai/udpplain.csv')

# %%
df1['Label'] = 'BENIGN'
df1.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62154 entries, 0 to 62153
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    MI_dir_L5_weight       62154 non-null  float64
#  1    MI_dir_L5_mean         62154 non-null  float64
#  2    MI_dir_L5_variance     62154 non-null  float64
#  3    MI_dir_L3_weight       62154 non-null  float64
#  4    MI_dir_L3_mean         62154 non-null  float64
#  5    MI_dir_L3_variance     62154 non-null  float64
#  6    MI_dir_L1_weight       62154 non-null  float64
#  7    MI_dir_L1_mean         62154 non-null  float64
#  8    MI_dir_L1_variance     62154 non-null  float64
#  9    MI_dir_L0.1_weight     62154 non-null  float64
#  10   MI_dir_L0.1_mean       62154 non-null  float64
#  11   MI_dir_L0.1_variance   62154 non-null  float64
#  12   MI_dir_L0.01_weight    62154 non-null  float64
#  13   MI_dir_L0.01_mean      62154 non-null  float64
# ...

# %%
df_gafgyt = pd.concat([df2, df3, df4, df5, df6])
df_gafgyt['Label'] = 'gafgyt'
df_gafgyt.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330096 entries, 0 to 104010
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       330096 non-null  float64
#  1    MI_dir_L5_mean         330096 non-null  float64
#  2    MI_dir_L5_variance     330096 non-null  float64
#  3    MI_dir_L3_weight       330096 non-null  float64
#  4    MI_dir_L3_mean         330096 non-null  float64
#  5    MI_dir_L3_variance     330096 non-null  float64
#  6    MI_dir_L1_weight       330096 non-null  float64
#  7    MI_dir_L1_mean         330096 non-null  float64
#  8    MI_dir_L1_variance     330096 non-null  float64
#  9    MI_dir_L0.1_weight     330096 non-null  float64
#  10   MI_dir_L0.1_mean       330096 non-null  float64
#  11   MI_dir_L0.1_variance   330096 non-null  float64
#  12   MI_dir_L0.01_weight    330096 non-null  float64
# ...

# %%
df_mirai = pd.concat([df7, df8, df9, df10, df11])
df_mirai['Label'] = 'mirai'
df_mirai.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 436010 entries, 0 to 56680
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       436010 non-null  float64
#  1    MI_dir_L5_mean         436010 non-null  float64
#  2    MI_dir_L5_variance     436010 non-null  float64
#  3    MI_dir_L3_weight       436010 non-null  float64
#  4    MI_dir_L3_mean         436010 non-null  float64
#  5    MI_dir_L3_variance     436010 non-null  float64
#  6    MI_dir_L1_weight       436010 non-null  float64
#  7    MI_dir_L1_mean         436010 non-null  float64
#  8    MI_dir_L1_variance     436010 non-null  float64
#  9    MI_dir_L0.1_weight     436010 non-null  float64
#  10   MI_dir_L0.1_mean       436010 non-null  float64
#  11   MI_dir_L0.1_variance   436010 non-null  float64
#  12   MI_dir_L0.01_weight    436010 non-null  float64
# ...

# %%
df = pd.concat([df1, df_gafgyt, df_mirai])

df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 828260 entries, 0 to 56680
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       828260 non-null  float64
#  1    MI_dir_L5_mean         828260 non-null  float64
#  2    MI_dir_L5_variance     828260 non-null  float64
#  3    MI_dir_L3_weight       828260 non-null  float64
#  4    MI_dir_L3_mean         828260 non-null  float64
#  5    MI_dir_L3_variance     828260 non-null  float64
#  6    MI_dir_L1_weight       828260 non-null  float64
#  7    MI_dir_L1_mean         828260 non-null  float64
#  8    MI_dir_L1_variance     828260 non-null  float64
#  9    MI_dir_L0.1_weight     828260 non-null  float64
#  10   MI_dir_L0.1_mean       828260 non-null  float64
#  11   MI_dir_L0.1_variance   828260 non-null  float64
#  12   MI_dir_L0.01_weight    828260 non-null  float64
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# mirai     436010
# gafgyt    330096
# BENIGN     62154
# Name: count, dtype: int64

# %%
pd.DataFrame(df).to_csv("./NBaIoT_5.csv", index=False)
