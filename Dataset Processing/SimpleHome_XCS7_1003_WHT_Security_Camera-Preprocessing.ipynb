# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/benign_traffic.csv')
df2 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/combo.csv')
df3 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/junk.csv')
df4 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/scan.csv')
df5 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/tcp.csv')
df6 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/gafgyt/udp.csv')
df7 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/ack.csv')
df8 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/scan.csv')
df9 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/syn.csv')
df10 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/udp.csv')
df11 = pd.read_csv('/home/administrator/dataset/NBaIoT/SimpleHome_XCS7_1003_WHT_Security_Camera/mirai/udpplain.csv')

# %%
df1['Label'] = 'BENIGN'
df1.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19528 entries, 0 to 19527
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    MI_dir_L5_weight       19528 non-null  float64
#  1    MI_dir_L5_mean         19528 non-null  float64
#  2    MI_dir_L5_variance     19528 non-null  float64
#  3    MI_dir_L3_weight       19528 non-null  float64
#  4    MI_dir_L3_mean         19528 non-null  float64
#  5    MI_dir_L3_variance     19528 non-null  float64
#  6    MI_dir_L1_weight       19528 non-null  float64
#  7    MI_dir_L1_mean         19528 non-null  float64
#  8    MI_dir_L1_variance     19528 non-null  float64
#  9    MI_dir_L0.1_weight     19528 non-null  float64
#  10   MI_dir_L0.1_mean       19528 non-null  float64
#  11   MI_dir_L0.1_variance   19528 non-null  float64
#  12   MI_dir_L0.01_weight    19528 non-null  float64
#  13   MI_dir_L0.01_mean      19528 non-null  float64
# ...

# %%
df_gafgyt = pd.concat([df2, df3, df4, df5, df6])
df_gafgyt['Label'] = 'gafgyt'
df_gafgyt.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316438 entries, 0 to 102979
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       316438 non-null  float64
#  1    MI_dir_L5_mean         316438 non-null  float64
#  2    MI_dir_L5_variance     316438 non-null  float64
#  3    MI_dir_L3_weight       316438 non-null  float64
#  4    MI_dir_L3_mean         316438 non-null  float64
#  5    MI_dir_L3_variance     316438 non-null  float64
#  6    MI_dir_L1_weight       316438 non-null  float64
#  7    MI_dir_L1_mean         316438 non-null  float64
#  8    MI_dir_L1_variance     316438 non-null  float64
#  9    MI_dir_L0.1_weight     316438 non-null  float64
#  10   MI_dir_L0.1_mean       316438 non-null  float64
#  11   MI_dir_L0.1_variance   316438 non-null  float64
#  12   MI_dir_L0.01_weight    316438 non-null  float64
# ...

# %%
df_mirai = pd.concat([df7, df8, df9, df10, df11])
df_mirai['Label'] = 'mirai'
df_mirai.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 514860 entries, 0 to 84435
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       514860 non-null  float64
#  1    MI_dir_L5_mean         514860 non-null  float64
#  2    MI_dir_L5_variance     514860 non-null  float64
#  3    MI_dir_L3_weight       514860 non-null  float64
#  4    MI_dir_L3_mean         514860 non-null  float64
#  5    MI_dir_L3_variance     514860 non-null  float64
#  6    MI_dir_L1_weight       514860 non-null  float64
#  7    MI_dir_L1_mean         514860 non-null  float64
#  8    MI_dir_L1_variance     514860 non-null  float64
#  9    MI_dir_L0.1_weight     514860 non-null  float64
#  10   MI_dir_L0.1_mean       514860 non-null  float64
#  11   MI_dir_L0.1_variance   514860 non-null  float64
#  12   MI_dir_L0.01_weight    514860 non-null  float64
# ...

# %%
df = pd.concat([df1, df_gafgyt, df_mirai])

df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 850826 entries, 0 to 84435
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       850826 non-null  float64
#  1    MI_dir_L5_mean         850826 non-null  float64
#  2    MI_dir_L5_variance     850826 non-null  float64
#  3    MI_dir_L3_weight       850826 non-null  float64
#  4    MI_dir_L3_mean         850826 non-null  float64
#  5    MI_dir_L3_variance     850826 non-null  float64
#  6    MI_dir_L1_weight       850826 non-null  float64
#  7    MI_dir_L1_mean         850826 non-null  float64
#  8    MI_dir_L1_variance     850826 non-null  float64
#  9    MI_dir_L0.1_weight     850826 non-null  float64
#  10   MI_dir_L0.1_mean       850826 non-null  float64
#  11   MI_dir_L0.1_variance   850826 non-null  float64
#  12   MI_dir_L0.01_weight    850826 non-null  float64
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# mirai     514860
# gafgyt    316438
# BENIGN     19528
# Name: count, dtype: int64

# %%
pd.DataFrame(df).to_csv("./NBaIoT_8.csv", index=False)
