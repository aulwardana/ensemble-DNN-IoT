# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/benign_traffic.csv')
df2 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/gafgyt/combo.csv')
df3 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/gafgyt/junk.csv')
df4 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/gafgyt/scan.csv')
df5 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/gafgyt/tcp.csv')
df6 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/gafgyt/udp.csv')
df7 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/mirai/ack.csv')
df8 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/mirai/scan.csv')
df9 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/mirai/syn.csv')
df10 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/mirai/udp.csv')
df11 = pd.read_csv('/home/administrator/dataset/NBaIoT/Philips_B120N10_Baby_Monitor/mirai/udpplain.csv')

# %%
df1['Label'] = 'BENIGN'
df1.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175240 entries, 0 to 175239
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       175240 non-null  float64
#  1    MI_dir_L5_mean         175240 non-null  float64
#  2    MI_dir_L5_variance     175240 non-null  float64
#  3    MI_dir_L3_weight       175240 non-null  float64
#  4    MI_dir_L3_mean         175240 non-null  float64
#  5    MI_dir_L3_variance     175240 non-null  float64
#  6    MI_dir_L1_weight       175240 non-null  float64
#  7    MI_dir_L1_mean         175240 non-null  float64
#  8    MI_dir_L1_variance     175240 non-null  float64
#  9    MI_dir_L0.1_weight     175240 non-null  float64
#  10   MI_dir_L0.1_mean       175240 non-null  float64
#  11   MI_dir_L0.1_variance   175240 non-null  float64
#  12   MI_dir_L0.01_weight    175240 non-null  float64
# ...

# %%
df_gafgyt = pd.concat([df2, df3, df4, df5, df6])
df_gafgyt['Label'] = 'gafgyt'
df_gafgyt.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 312723 entries, 0 to 105781
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       312723 non-null  float64
#  1    MI_dir_L5_mean         312723 non-null  float64
#  2    MI_dir_L5_variance     312723 non-null  float64
#  3    MI_dir_L3_weight       312723 non-null  float64
#  4    MI_dir_L3_mean         312723 non-null  float64
#  5    MI_dir_L3_variance     312723 non-null  float64
#  6    MI_dir_L1_weight       312723 non-null  float64
#  7    MI_dir_L1_mean         312723 non-null  float64
#  8    MI_dir_L1_variance     312723 non-null  float64
#  9    MI_dir_L0.1_weight     312723 non-null  float64
#  10   MI_dir_L0.1_mean       312723 non-null  float64
#  11   MI_dir_L0.1_variance   312723 non-null  float64
#  12   MI_dir_L0.01_weight    312723 non-null  float64
# ...

# %%
df_mirai = pd.concat([df7, df8, df9, df10, df11])
df_mirai['Label'] = 'mirai'
df_mirai.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 610714 entries, 0 to 80807
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count   Dtype
# ---   ------                 --------------   -----
#  0    MI_dir_L5_weight       610714 non-null  float64
#  1    MI_dir_L5_mean         610714 non-null  float64
#  2    MI_dir_L5_variance     610714 non-null  float64
#  3    MI_dir_L3_weight       610714 non-null  float64
#  4    MI_dir_L3_mean         610714 non-null  float64
#  5    MI_dir_L3_variance     610714 non-null  float64
#  6    MI_dir_L1_weight       610714 non-null  float64
#  7    MI_dir_L1_mean         610714 non-null  float64
#  8    MI_dir_L1_variance     610714 non-null  float64
#  9    MI_dir_L0.1_weight     610714 non-null  float64
#  10   MI_dir_L0.1_mean       610714 non-null  float64
#  11   MI_dir_L0.1_variance   610714 non-null  float64
#  12   MI_dir_L0.01_weight    610714 non-null  float64
# ...

# %%
df = pd.concat([df1, df_gafgyt, df_mirai])

df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1098677 entries, 0 to 80807
# Data columns (total 116 columns):
#  #    Column                 Non-Null Count    Dtype
# ---   ------                 --------------    -----
#  0    MI_dir_L5_weight       1098677 non-null  float64
#  1    MI_dir_L5_mean         1098677 non-null  float64
#  2    MI_dir_L5_variance     1098677 non-null  float64
#  3    MI_dir_L3_weight       1098677 non-null  float64
#  4    MI_dir_L3_mean         1098677 non-null  float64
#  5    MI_dir_L3_variance     1098677 non-null  float64
#  6    MI_dir_L1_weight       1098677 non-null  float64
#  7    MI_dir_L1_mean         1098677 non-null  float64
#  8    MI_dir_L1_variance     1098677 non-null  float64
#  9    MI_dir_L0.1_weight     1098677 non-null  float64
#  10   MI_dir_L0.1_mean       1098677 non-null  float64
#  11   MI_dir_L0.1_variance   1098677 non-null  float64
#  12   MI_dir_L0.01_weight    1098677 non-null  float64
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# mirai     610714
# gafgyt    312723
# BENIGN    175240
# Name: count, dtype: int64

# %%
pd.DataFrame(df).to_csv("./NBaIoT_4.csv", index=False)
